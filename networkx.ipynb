# %%
import networkx as nx
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
vector={}
vector["start"]=["U","R"]
vector["U"]=["UR","UU"]
vector["R"]=["RR","RU"]

g = nx.DiGraph(vector)
nx.draw_networkx(g,pos=nx.graphviz_la)

# %%
nx.draw(g)
